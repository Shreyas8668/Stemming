# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
words = ["playing", "played", "plays", "player"]

for w in words:
    print(w, "→", ps.stem(w))
# Out:
# playing → play
# played → play
# plays → play
# player → player

# %%
words=["playing",
"played",
"plays",
"runner",
"running",
"easily",
"fairly"
"happiness",
"studies",
"studying"
 ]

# %% [markdown]
#  ### porter stemming

# %%
from nltk.stem import PorterStemmer

# %%
stemming =PorterStemmer()

# %%
for word in words:
    print(word+"--->"+stemming.stem(word))
# Out:
# playing--->play
# played--->play
# plays--->play
# runner--->runner
# running--->run
# easily--->easili
# fairlyhappiness--->fairlyhappi
# studies--->studi
# studying--->studi

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
from nltk.stem import RegexpStemmer

# %%
reg_steamer=RegexpStemmer('ing$|s$|e$|able$',min=4)

# %%
reg_steamer.stem('eating')
# Out:
# 'eat'

# %%
reg_steamer.stem('ingeating')
# Out:
# 'ingeat'

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer=SnowballStemmer('english')

# %%
for word in word:
    print(word+"---->"+snowballstemmer.stem(word))
# Out:
# s---->s
# t---->t
# u---->u
# d---->d
# y---->y
# i---->i
# n---->n
# g---->g

# %%
snowballstemmer.stem("fairly")
# Out:
# 'fair'

# %%
snowballstemmer.stem('sportingly')
# Out:
# 'sport'

# %%
snowballstemmer.stem('going')
# Out:
# 'go'
